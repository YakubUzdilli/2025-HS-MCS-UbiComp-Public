# %%
# Import required libraries for training and using the ExtraTreesClassifier
import os
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import StandardScaler
import joblib

# Read data
recording_location = './'
all_features_csv = os.path.join(recording_location, './Data/FeatureFiles/feature_list_all.csv')
df = pd.read_csv(all_features_csv)

# Define most significant features based on Random Forest feature importance analysis
# These are the actual top 8 features from the comprehensive analysis
significant_features = [
    "xDir",           # Most important (0.236)
    "fixDensPerBB",   # Second most important (0.189)
    "meanFix",        # Third most important (0.156)
    "maxDis", 
    "stdDisp",
    "stdFix",
    "varFix",
    "varDis"
]

# Prepare features and labels for training
features = df[significant_features]
labels = df['label']

# Create and fit the scaler on all training data
scaler = StandardScaler()
scaler.fit(features)
scaled_features = scaler.transform(features)

# Train ExtraTrees classifier on all data (no test split needed for production model)
extra_trees = ExtraTreesClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)
extra_trees.fit(scaled_features, labels)

print("Model training completed successfully!")
print(f"Features used: {significant_features}")
print(f"Classes: {extra_trees.classes_}")

# Create Models directory if it doesn't exist
os.makedirs('./Models', exist_ok=True)

# Save the trained model and scaler for use by HoloLens application
joblib.dump(extra_trees, './Models/extra_trees_classifier.joblib')
joblib.dump(scaler, './Models/feature_scaler.joblib')
print("Model and scaler saved to ./Models/ directory")
# Out:
# Accuracy: 0.805
# Classification Report:
#               precision    recall  f1-score   support
#
#   Inspection       0.83      0.77      0.80        26
#      Reading       0.79      0.88      0.84        26
#       Search       0.79      0.76      0.78        25
#
#     accuracy                           0.81        77
#    macro avg       0.81      0.80      0.80        77
# weighted avg       0.81      0.81      0.80        77
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 73
#      71 # Save the model and scaler for later use
#      72 import joblib
# ---> 73 joblib.dump(extra_trees, './Models/extra_trees_classifier.joblib')
#      74 joblib.dump(scaler, './Models/feature_scaler.joblib')
#
# ...

# %%
# Example: How to use the trained classifier for new predictions
# This is what your HoloLens application would do

def predict_activity(gaze_features):
    """
    Predicts the activity type based on gaze features from HoloLens
    
    Parameters:
    gaze_features (dict or list): Dictionary with feature names as keys and values,
                                 or list of values in the correct order
    
    Returns:
    tuple: (predicted_class, confidence_scores)
    """
    
    # Load the trained model and scaler
    model = joblib.load('./Models/extra_trees_classifier.joblib')
    scaler = joblib.load('./Models/feature_scaler.joblib')
    
    # Convert input to DataFrame if it's a dictionary
    if isinstance(gaze_features, dict):
        features_df = pd.DataFrame([gaze_features])
    else:
        # Assume it's a list/array with features in correct order
        features_df = pd.DataFrame([gaze_features], columns=significant_features)
    
    # Scale the features using the same scaler from training
    scaled_features = scaler.transform(features_df)
    
    # Make prediction
    prediction = model.predict(scaled_features)[0]
    confidence_scores = model.predict_proba(scaled_features)[0]
    
    return prediction, confidence_scores

# Example usage:
print("Example of how to use the classifier:")
print("=====================================")

# Example feature values (you would get these from HoloLens gaze data)
example_features = {
    "xDir": 0.5,
    "fixDensPerBB": 0.8,
    "meanFix": 250.0,
    "maxDis": 15.2,
    "stdDisp": 3.1,
    "stdFix": 45.0,
    "varFix": 2025.0,
    "varDis": 9.61
}

# Or as a list (make sure order matches significant_features)
# example_features = [0.5, 0.8, 250.0, 15.2, 3.1, 45.0, 2025.0, 9.61]

predicted_class, confidence = predict_activity(example_features)
print(f"Predicted activity: {predicted_class}")
print(f"Confidence scores: {dict(zip(['Inspection', 'Reading', 'Search'], confidence))}")

# %% [markdown]
# # ExtraTreesClassifier for HoloLens Gaze Activity Recognition
#
# This notebook trains an ExtraTreesClassifier to recognize user activities (Reading, Inspection, Search) based on gaze features from HoloLens data.
#
# ## Required Features (in this exact order):
# 1. **xDir**: Directional movement in X-axis
# 2. **fixDensPerBB**: Fixation density per bounding box
# 3. **meanFix**: Mean fixation duration
# 4. **maxDis**: Maximum distance between fixations
# 5. **stdDisp**: Standard deviation of dispersion
# 6. **stdFix**: Standard deviation of fixation duration
# 7. **varFix**: Variance of fixation duration
# 8. **varDis**: Variance of distance between fixations
#
# ## Output Classes:
# - **Inspection**: Visual inspection activity
# - **Reading**: Reading activity
# - **Search**: Search activity
#
# ## Files Generated:
# - `./Models/extra_trees_classifier.joblib`: Trained classifier model
# - `./Models/feature_scaler.joblib`: Feature scaler (must be applied to new data)
